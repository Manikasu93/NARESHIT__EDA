# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
f_p='visa.csv'
visa_df=pd.read_csv(f_p)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
f,i,n=plt.hist(visa_df['prevailing_wage'],bins=40)

# %%
l=2.13670000e+00
u=7.98234003e+03

c1=visa_df['prevailing_wage']>=l
c2=visa_df['prevailing_wage']<u
len(visa_df[c1&c2])
# Out:
# 2992

# %%
len(visa_df[visa_df['prevailing_wage'].between(2.13670000e+00,7.98234003e+03)])
# Out:
# 2992

# %%
print(len(visa_df[visa_df['prevailing_wage'].between(7.98234003e+03,1.59625434e+04)]))
print(len(visa_df[visa_df['prevailing_wage'].between(1.59625434e+04,2.39427467e+04)]))
print(len(visa_df[visa_df['prevailing_wage'].between(2.39427467e+04,3.19229500e+04)]))
print(len(visa_df[visa_df['prevailing_wage'].between(3.19229500e+04,4.78833567e+04)]))
print(len(visa_df[visa_df['prevailing_wage'].between(4.78833567e+04,5.58635600e+04)]))
print(len(visa_df[visa_df['prevailing_wage'].between(5.58635600e+04,6.38437634e+04)]))
# Out:
# 871
# 1005
# 1170
# 2676
# 1385
# 1443

# %%
def frequency(l,u):
    c1=visa_df['prevailing_wage']>=l
    c2=visa_df['prevailing_wage']<u
    c=c1&c2
    print(len(visa_df[c1&c2]))
frequency(2.13670000e+00,7.98234003e+03)
# Out:
# 2992

# %%
print(f)
print(i)
print(n)
# Out:
# [2992.  871. 1005. 1170. 1242. 1434. 1385. 1443. 1444. 1445. 1457. 1335.
#  1268. 1217. 1088.  978.  807.  645.  509.  373.  264.  144.  105.  111.
#   107.   99.   88.   79.   65.   64.   58.   53.   33.   33.   29.   19.
#     7.    3.    6.    5.]
# [2.13670000e+00 7.98234003e+03 1.59625434e+04 2.39427467e+04
#  3.19229500e+04 3.99031534e+04 4.78833567e+04 5.58635600e+04
#  6.38437634e+04 7.18239667e+04 7.98041700e+04 8.77843734e+04
#  9.57645767e+04 1.03744780e+05 1.11724983e+05 1.19705187e+05
#  1.27685390e+05 1.35665593e+05 1.43645797e+05 1.51626000e+05
#  1.59606203e+05 1.67586407e+05 1.75566610e+05 1.83546813e+05
#  1.91527017e+05 1.99507220e+05 2.07487423e+05 2.15467627e+05
#  2.23447830e+05 2.31428033e+05 2.39408237e+05 2.47388440e+05
#  2.55368643e+05 2.63348847e+05 2.71329050e+05 2.79309253e+05
#  2.87289457e+05 2.95269660e+05 3.03249863e+05 3.11230067e+05
#  3.19210270e+05]
# <BarContainer object of 40 artists>

# %% [markdown]
# # Task-1
# create a dataframe
#
#
# lower  upper frequency
#
#
# 2.136 7.982   2992

# %%
# task-2
# in seaborns how to plot histogram

# %% [markdown]
# $BOXPLOT$

# %% [markdown]
# - IN BOXPLOT WE HAVE
#     - Q1: 25p value
#     - Q2: 50p value
#     - Q3: 75p value
#     - IQR:Q3-Q1
#     - mild outliers Q1-1.5IQR AND Q3+1.5IQR
#     - HUGE OUTLIERS Q1-3IQR AND Q3+3IQR

# %% [markdown]
#            Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#      flier             <----------->            fliers
#                             IQR

# %%
plt.boxplot(visa_df['prevailing_wage'])
plt.show()

# black dots are outliers
# orange line is median

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# %% [markdown]
# ## OUTLIER ANALYSIS

# %% [markdown]
# **steps in outlieranalysis**
# - step1: find the q1,q2 and q3
#      - np.percentile(column data,q)
# - step2: calculate the IQR
#      - IQR= Q3-Q1
# - step3: calculate the lower and upper boundary
#      - lb: Q1-1.5IQR
#      - ub: Q3-1.5IQR
# - step4: Find the Outliersdf
#      - c1: column data<Lb
#      - c2: column data>UB
#      - c: apply the main condition
#      - main data[c

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR
con1=visa_df['prevailing_wage']>ub
con2=visa_df['prevailing_wage']<lb
con=visa_df[con1|con2]
outliers_df=con
len(outliers_df)
# Out:
# 427

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR
con1=visa_df['prevailing_wage']>ub
con2=visa_df['prevailing_wage']<lb
con=visa_df[con1|con2]
outliers_df=con
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=q3-q1
ub=q3+1.5*IQR
lb=q1-1.5*IQR
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con=con1&con2
nonoutliers_df=visa_df[con]
nonoutliers_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# *comparing original outliersd with nonoutliers data*
#
# -

# %%
plt.hist(visa_df['prevailing_wage'])
plt.hist(nonoutliers_df['prevailing_wage'])
plt.show()

# %%
plt.boxplot(visa_df['prevailing_wage'])
plt.boxplot(nonoutliers_df['prevailing_wage'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.title('original data')
plt.hist(visa_df['prevailing_wage'],bins=40)

plt.subplot(2,2,2)
plt.title('nonoutliers data')
plt.hist(nonoutliers_df['prevailing_wage'],bins=40)

plt.subplot(2,2,3)
plt.title('original data')
plt.boxplot(visa_df['prevailing_wage'])




plt.subplot(2,2,4)
plt.title('non outliers data ')
plt.boxplot(nonoutliers_df['prevailing_wage'])
plt.show()

# %% [markdown]
# ## How to deal the outliers
#
# **Drop the outliers**
#   - we can drop the outliers if outliers percentage < 25%
#   - but this is not recommended , we lost other columns data also
#
# **Impute with median values**
#   - As we know that median does not effect by outliers
#   - so it is good practice we can impute the outliers with median value
#
# **cap with q3 or q1 value**
#   - if outliers are persent less than lower bound then fill with Q1
#   - if outliers are more than upper bound then fill with Q3

# %%
#Task-3
# read the each observation from prevailing wage
# if that observation <lb or<ub :fill with median value
# else : keep as it is 


# take empty list =[]
# median= visa_df['pwage'].medain()
# for i in visa_df['pwage']:
# if i<lb or i>ub:
# emptylist.append(median)
# else:
# emptylist.append(i)

# %%
l=[]
median=visa_df['prevailing_wage'].median()
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        l.append(median)
    else:
        l.append(i)
len(l)
# Out:
# 25480

# %%
# task-2
# in seaborns how to plot histogram

# %%
plt.figure(figsize=(8,6))
sns.histplot(visa_df['prevailing_wage'],color='red')
plt.show()

# %% [markdown]
# # Task-1
# create a dataframe
#
#
# lower  upper frequency
#
#
# 2.136 7.982   2992

# %%
print(i)
print(f)
print(n)
# Out:
# 70876.91
# [2992.  871. 1005. 1170. 1242. 1434. 1385. 1443. 1444. 1445. 1457. 1335.
#  1268. 1217. 1088.  978.  807.  645.  509.  373.  264.  144.  105.  111.
#   107.   99.   88.   79.   65.   64.   58.   53.   33.   33.   29.   19.
#     7.    3.    6.    5.]
# <BarContainer object of 40 artists>

# %%
i,f,n=plt.hist(visa_df['prevailing_wage'],bins=40)

lb=f[:-1]
ub=f[1:]

pd.DataFrame(zip(lb,ub,i),columns=['lower','upper','frequency'])
# Out:
#             lower          upper  frequency
# 0        2.136700    7982.340033     2992.0
# 1     7982.340033   15962.543365      871.0
# 2    15962.543365   23942.746698     1005.0
# 3    23942.746698   31922.950030     1170.0
# 4    31922.950030   39903.153363     1242.0
# 5    39903.153363   47883.356695     1434.0
# 6    47883.356695   55863.560028     1385.0
# 7    55863.560028   63843.763360     1443.0
# 8    63843.763360   71823.966693     1444.0
# 9    71823.966693   79804.170025     1445.0
# 10   79804.170025   87784.373358     1457.0
# 11   87784.373358   95764.576690     1335.0
# 12   95764.576690  103744.780023     1268.0
# 13  103744.780023  111724.983355     1217.0
# 14  111724.983355  119705.186688     1088.0
# 15  119705.186688  127685.390020      978.0
# 16  127685.390020  135665.593353      807.0
# 17  135665.593353  143645.796685      645.0
# 18  143645.796685  151626.000018      509.0
# 19  151626.000018  159606.203350      373.0
# ...

# %% [markdown]
# 07-March-2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
f_p='visa.csv'
visa_df=pd.read_csv(f_p)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR

m=visa_df['prevailing_wage'].median()
l=[]
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        l.append(median)
    else:
        l.append(i)
l
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.20999999999,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.20999999999,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
# ...

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR

m=visa_df['prevailing_wage'].median()
l=[]
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        l.append(median)
    else:
        l.append(i)
visa_df['prevailing_wage_new']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.boxplot(visa_df['prevailing_wage_new'])
plt.show()

# %% [markdown]
# **np.where**

# %%
# read the data again

visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
- above replace one we use a traditional approach
-

# %%
dict1={'name':['A','B','C','D'],'num':[1,2,3,4]}
d=pd.DataFrame(dict1)
d
# Out:
#   name  num
# 0    A    1
# 1    B    2
# 2    C    3
# 3    D    4

# %%
# i want to replace with 100 num which has >2
# other wise keep same number
l=[]
for i in d['num']:
    if i>2:
        l.append(100)
    else:
        l.append(i)
d['num']=l
d
# Out:
#   name  num
# 0    A    1
# 1    B    2
# 2    C  100
# 3    D  100

# %% [markdown]
# np.where(con,True,False)
#
# #condition
#
#   - con=d['num']>2
#
# #true value
#
#   - t=100
#
# #false value
#
#   - d['num']

# %%
m=np.where(d['num']>2,100,d['num'])

d['num']=m
d
# Out:
#   name  num
# 0    A    1
# 1    B    2
# 2    C  100
# 3    D  100

# %%
q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
q2=round(np.percentile(visa_df['prevailing_wage'],50),2)
q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR

m=visa_df['prevailing_wage'].median()
l=[]
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        l.append(median)
    else:
        l.append(i)
visa_df['prevailing_wage_new']=l
visa_df

# %%
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
con=c1|c2
t=m
f=visa_df['prevailing_wage']

visa_df['prevailing_wage']=np.where(con,t,f)
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476     70308.2100
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
con=c1|c2
t=m
f=visa_df['prevailing_wage']

visa_df['prevailing_wage']=np.where(con,t,f)
plt.boxplot(visa_df['prevailing_wage'])
plt.show()
